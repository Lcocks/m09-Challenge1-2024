# %%
""" From Rivanna after creating Challenge1 repo.
***********First created a repo in github; then in rivanna made a wd with mkdir, then created the __init__.py & jabber.py files, then edit jabber.py with nano, then edit __init__.py, 
then edit setup.py, then pip install . to install this package using this setup file (this action failed), then 



For details see https://www.rc.virginia.edu/2024/10/transition-from-anaconda-to-miniforge-october-15-2024/
epx8hh@rivanna> pwd
/home/epx8hh
epx8hh@rivanna> cd Documents/MSDS/DS5100/
epx8hh@rivanna> ls
DS5100-activities-24-08  DS5100-epx8hh
epx8hh@rivanna> git clone git@github.com:Lcocks/m09-Challenge1-2024.git
Cloning into 'm09-Challenge1-2024'...
remote: Enumerating objects: 5, done.
remote: Counting objects: 100% (5/5), done.
remote: Compressing objects: 100% (5/5), done.
remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
Receiving objects: 100% (5/5), done.
epx8hh@rivanna> ls
DS5100-activities-24-08  DS5100-epx8hh  m09-Challenge1-2024
epx8hh@rivanna> cd m09-Challenge1-2024/
epx8hh@rivanna> ls
LICENSE  README.md
epx8hh@rivanna> ls -al
total 11
drwx--S--- 3 epx8hh users 4096 Oct 29 19:56 .
drwx--S--- 5 epx8hh users 8192 Oct 29 19:56 ..
drwx--S--- 8 epx8hh users 4096 Oct 29 19:56 .git
-rw------- 1 epx8hh users 3139 Oct 29 19:56 .gitignore
-rw------- 1 epx8hh users 1063 Oct 29 19:56 LICENSE
-rw------- 1 epx8hh users   50 Oct 29 19:56 README.md
epx8hh@rivanna> pwd
/home/epx8hh/Documents/MSDS/DS5100/m09-Challenge1-2024
epx8hh@rivanna> mkdir challenge1
epx8hh@rivanna> ll
total 2
drwx--S--- 2 epx8hh users 4096 Oct 29 20:00 challenge1
-rw------- 1 epx8hh users 1063 Oct 29 19:56 LICENSE
-rw------- 1 epx8hh users   50 Oct 29 19:56 README.md
epx8hh@rivanna> touch setup.py
epx8hh@rivanna> ll
total 2
drwx--S--- 2 epx8hh users 4096 Oct 29 20:00 challenge1
-rw------- 1 epx8hh users 1063 Oct 29 19:56 LICENSE
-rw------- 1 epx8hh users   50 Oct 29 19:56 README.md
-rw------- 1 epx8hh users    0 Oct 29 20:01 setup.py
epx8hh@rivanna> more setup.py
epx8hh@rivanna> cd challenge1/
epx8hh@rivanna> touch __init__.py
epx8hh@rivanna> ll
total 0
-rw------- 1 epx8hh users 0 Oct 29 20:01 __init__.py
epx8hh@rivanna> touch jabber.py
epx8hh@rivanna> ;;
-bash: syntax error near unexpected token `;;'
epx8hh@rivanna> ls -lR
.:
total 0
-rw------- 1 epx8hh users 0 Oct 29 20:01 __init__.py
-rw------- 1 epx8hh users 0 Oct 29 20:02 jabber.py
epx8hh@rivanna> ls -l
total 0
-rw------- 1 epx8hh users 0 Oct 29 20:01 __init__.py
-rw------- 1 epx8hh users 0 Oct 29 20:02 jabber.py
epx8hh@rivanna> nano jabber.py 
epx8hh@rivanna> nano jabber.py 
epx8hh@rivanna> pwd
/home/epx8hh/Documents/MSDS/DS5100/m09-Challenge1-2024/challenge1
epx8hh@rivanna> nano __init__.py 
epx8hh@rivanna> nano __init__.py 
epx8hh@rivanna> nano __init__.py 
epx8hh@rivanna> ll
total 1
-rw------- 1 epx8hh users 32 Oct 29 20:10 __init__.py
-rw------- 1 epx8hh users 78 Oct 29 20:08 jabber.py
epx8hh@rivanna> cd ..
epx8hh@rivanna> pwd
/home/epx8hh/Documents/MSDS/DS5100/m09-Challenge1-2024
epx8hh@rivanna> nano setup.py 
epx8hh@rivanna> nano setup.py 
epx8hh@rivanna> pip install .
Defaulting to user installation because normal site-packages is not writeable
Processing /sfs/gpfs/tardis/home/epx8hh/Documents/MSDS/DS5100/m09-Challenge1-2024
  Preparing metadata (setup.py) ... error
  error: subprocess-exited-with-error
  
  × python setup.py egg_info did not run successfully.
  │ exit code: 1
  ╰─> [7 lines of output]
      running egg_info
      creating /tmp/pip-pip-egg-info-otsjcoj4/Demo.egg-info
      writing /tmp/pip-pip-egg-info-otsjcoj4/Demo.egg-info/PKG-INFO
      writing dependency_links to /tmp/pip-pip-egg-info-otsjcoj4/Demo.egg-info/dependency_links.txt
      writing top-level names to /tmp/pip-pip-egg-info-otsjcoj4/Demo.egg-info/top_level.txt
      writing manifest file '/tmp/pip-pip-egg-info-otsjcoj4/Demo.egg-info/SOURCES.txt'
      error: package directory 'demo' does not exist
      [end of output]
  
  note: This error originates from a subprocess, and is likely not a problem with pip.
error: metadata-generation-failed

× Encountered error while generating package metadata.
╰─> See above for output.

note: This is an issue with the package mentioned above, not pip.
hint: See above for details.
epx8hh@rivanna> python 
Python 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:40:35) [GCC 12.3.0] on linux
Type "help", "copyright", "credits" or "license" for more information.
>>> improt demo
  File "<stdin>", line 1
    improt demo
           ^^^^
SyntaxError: invalid syntax
>>> import demo
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
ModuleNotFoundError: No module named 'demo'
>>> quit()
epx8hh@rivanna> cd
epx8hh@rivanna> python
Python 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:40:35) [GCC 12.3.0] on linux
Type "help", "copyright", "credits" or "license" for more information.
>>> import demo
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
ModuleNotFoundError: No module named 'demo'
>>> quit()
epx8hh@rivanna> cd Documents/MSDS/DS5100/
epx8hh@rivanna> ls
DS5100-activities-24-08  DS5100-epx8hh  m09-Challenge1-2024
epx8hh@rivanna> cd m09
-bash: cd: m09: No such file or directory
epx8hh@rivanna> cd m09-Challenge1-2024/
epx8hh@rivanna> ls
challenge1  LICENSE  README.md  setup.py
epx8hh@rivanna> git add .
epx8hh@rivanna> git commit -m"First commit."
[main 1d4e61c] First commit.
 3 files changed, 16 insertions(+)
 create mode 100644 challenge1/__init__.py
 create mode 100644 challenge1/jabber.py
 create mode 100644 setup.py
epx8hh@rivanna> git push
Enumerating objects: 7, done.
Counting objects: 100% (7/7), done.
Delta compression using up to 40 threads
Compressing objects: 100% (5/5), done.
Writing objects: 100% (6/6), 758 bytes | 758.00 KiB/s, done.
Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
To github.com:Lcocks/m09-Challenge1-2024.git
   8b18b18..1d4e61c  main -> main
epx8hh@rivanna> 
"""
